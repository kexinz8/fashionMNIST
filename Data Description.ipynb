# %%
df_train = pd.read_csv('fashion-mnist_train.csv')
df_test = pd.read_csv('fashion-mnist_test.csv')
df_train_ = df_train.drop(['label'], axis = 1).to_numpy()
train_labels = df_train['label']
test_labels = df_test['label']

# %%
# import libraries 
import pandas as pd #dataframes
import numpy as np #data statistical analysis 
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns
import random

# %matplotlib inline
sns.set_style("whitegrid")

# %%
#df_train.head()

# %%
# Create training and testing arrays
train = np.array(df_train, dtype='float32')
test = np.array(df_test, dtype='float32')

# %%
train.shape
# Out:
# (60000, 785)

# %%
#df_train['label']

labels_types = range(10)
labels = [[],[],[],[],[],[],[],[],[],[]]
for i in range(len(df_train)):
    for label in labels_types:
        if ((df_train['label'][i]) == label):
            labels[label].append(i)

# %%
select_index = []
for i in range(10):
    select_index.append(labels[i][0:10])

#labels[0][0:10]

# %%
select_index
# Out:
# [[3, 10, 13, 24, 31, 41, 44, 80, 92, 102],
#  [29, 39, 54, 69, 72, 84, 93, 109, 113, 137],
#  [0, 14, 15, 34, 38, 49, 51, 52, 70, 78],
#  [4, 17, 18, 19, 33, 36, 58, 63, 73, 76],
#  [5, 6, 8, 22, 23, 25, 26, 37, 53, 55],
#  [7, 30, 32, 45, 50, 60, 61, 64, 66, 79],
#  [2, 40, 43, 46, 62, 74, 82, 87, 88, 90],
#  [21, 28, 35, 47, 48, 86, 94, 111, 115, 129],
#  [9, 11, 20, 27, 57, 65, 68, 71, 75, 83],
#  [1, 12, 16, 42, 56, 67, 114, 117, 128, 148]]

# %%
df_train['label'][0]
# Out:
# 2

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 10
L_grid = 10

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations


fig, axes = plt.subplots(W_grid, L_grid, figsize=(10,10))

axes = axes.ravel() # flaten the 10 x 10 matrix into 100 array

n_train = len(train) # get the length of the train dataset

# Select a random number from 0 to n_train
for i in np.arange(0, W_grid): # create evenly spaces variables 
    for j in np.arange(0, L_grid):
        # Select index
        index = select_index[i][j]
        # read and display an image with the selected index    
        axes[10*i + j].imshow(train[index,1:].reshape((28,28)) )
        label_index = int(train[index,0])
        axes[10*i + j].set_title(class_names[label_index], fontsize=8)
        axes[10*i + j].axis('off')

plt.subplots_adjust(hspace=0.4)

# %%
# histgram of train labels

g = sns.countplot(train_labels)

train_labels.value_counts()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 2    6000
# 9    6000
# 6    6000
# 0    6000
# 3    6000
# 4    6000
# 5    6000
# 8    6000
# 7    6000
# 1    6000
# Name: label, dtype: int64

# %%
# histgram of train labels

g = sns.countplot(test_labels)

test_labels.value_counts()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0    1000
# 1    1000
# 2    1000
# 3    1000
# 8    1000
# 6    1000
# 5    1000
# 4    1000
# 7    1000
# 9    1000
# Name: label, dtype: int64

# %%
# percentile list
perc =[.20, .40, .60, .80]

# calling describe method
desc = df_train.drop(['label'], axis = 1).describe(percentiles = perc)
  
# display
desc
# Out:
#              pixel1        pixel2        pixel3        pixel4        pixel5  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.000900      0.006150      0.035333      0.101933      0.247967
# std        0.094689      0.271011      1.222324      2.452871      4.306912
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 20%        0.000000      0.000000      0.000000      0.000000      0.000000
# 40%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 60%        0.000000      0.000000      0.000000      0.000000      0.000000
# 80%        0.000000      0.000000      0.000000      0.000000      0.000000
# max       16.000000     36.000000    226.000000    164.000000    227.000000
#
#              pixel6        pixel7        pixel8        pixel9       pixel10  \
# ...

# %%
# boxplot of five random pixels
boxplot = df_train.boxplot(column=['pixel1', 'pixel100', 'pixel200', 'pixel300', 'pixel400'])
